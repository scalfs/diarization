# %% [markdown]
# # Steps in data preparation
#
# 1. Load the audio using librosa
# 2. Get the duration using librosa.get_duration
# 3. Calculate each frame width in ms
# 4. Split the audio on VAD (Below 20db is silence)
# 5. For each split calculate mel (180 frames)
# 6. np.transpose the data Ex: (1,40,180) to (180,1,40)

# %%
# All imports
import os, sys, logging
import datetime
import time, shutil, pickle
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics.pairwise import cosine_similarity
from scipy.ndimage.filters import gaussian_filter
from configuration import get_config

config = get_config()
log_file = os.path.abspath("data-generation-for-uisrnn.logs")
logging.basicConfig(
    filename=log_file,
    level=logging.DEBUG,
    format="%(asctime)s:%(levelname)s:%(message)s"
    )
print(f'Log path: {log_file}')

# %matplotlib inline
# Out:
# Namespace(noise_path='/datadrive2/dalon/diarization-experiments/Speaker_Verification/data/VCTK-Corpus/noise', train_path='/datadrive2/dalon/diarization-experiments/Speaker_Verification/data/VCTK-Corpus/train', test_path='/datadrive2/dalon/diarization-experiments/Speaker_Verification/data/VCTK-Corpus/test', tdsv=False, sr=16000, nfft=512, window=0.025, hop=0.01, tdsv_frame=160, tisv_frame=160, tisv_frame_min=50, hidden=768, proj=256, num_layer=3, restore=False, model_path='./tisv_model', model_num=3, train=False, N=4, M=5, noise_filenum=16, loss='softmax', optim='sgd', lr=0.001, beta1=0.5, beta2=0.9, iteration=100000, comment='', max_batch_utterances=1000)
# Log path: /home/jovyan/work/voxsrc21-dia/data-generation-for-uisrnn.logs

# %% [markdown]
# # All configurations below:

# %%
random_state = 222 # random seed
config.N = 64 # Number of speakers per batch
config.M = 10 # Number of utterences per speaker
config.iteration = 50000000 # Number of iterations to run
config.lr = 1e-3
config.hidden = 768 # hidden state dimension of lstm
config.proj = 256 # projection dimension of lstm
# config.restore = True
config.model_num = 1
logging.info(f'N={config.N}, M={config.M}')
logging.info(f'Model restore: {config.restore}, Model number: {config.model_num}')

# Configurations

#_____________ Parameters to tune on dev set _______________________
# VAD param
# Changing to 25, which will give slightly better intervals, 20 gives very short intervals
vad_threshold = 25 # threshold for voice activity detection

# Segment param
acceptable_shortseg_dur = 0.2 # in second
#^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# model parameters
model_path = '/home/jovyan/work/voxsrc21-dia/models/model.uisrnn-1' # model save path
data_path = '/home/jovyan/work/datasets/voxceleb-1/sample/wav'
save_dir_path = '/home/jovyan/work/voxsrc21-dia/embeddings'
os.makedirs(save_dir_path, exist_ok=True)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# I'm saving only 2 embeddings i.e. first and last tisv_frames for given interval in an audio. So each .npy
# embedding file will have a shape of (2, 256)

# %%
# for base_id in os.listdir(dataset_path):
#     print(base_id)
# #     speakerid = folder
#     folder = os.path.join(dataset_path, folder)
for base_id in os.listdir(data_path):
    for video_id in os.listdir(os.path.join(data_path, base_id)):
        if video_id.startswith('.'): #hidden folders
            continue;
        print(video_id)
        for audio_id in os.listdir(os.path.join(data_path, base_id, video_id)):
            print(audio_id)
# Out:
# 1zcIwhmdeo4
# 00001.wav
# 00002.wav
# 00003.wav
# 7gWzIy6yIIk
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 7w0IBEWc9Qw
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 9mQ11vBs1wc
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# DtdEYdViWdw
# 00001.wav
# 00002.wav
# 00003.wav
# J9lHsKG98U8
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# 00019.wav
# 00020.wav
# 00021.wav
# 00022.wav
# 00023.wav
# 00024.wav
# 00025.wav
# 00026.wav
# Y8hIVOBuels
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# eWIX7sfn-M0
# 00001.wav
# utrA-v8pPm4
# 00001.wav
# zELwAz2W6hM
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
#
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# uoAEmu-GbjQ
# 00001.wav
# wNQ9HultFDs
# 00001.wav
# 2wHaOQUrkHU
# 00001.wav
# 37mbJ9bXK28
# 00001.wav
# 5xGJYiNH2Jw
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# 00019.wav
# 7FOcBtZM-rI
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 7OacMAs-Crc
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 8gWjr_-ROCc
# 00001.wav
# 00002.wav
# CsU9a10ccxA
# 00001.wav
# 00002.wav
# FDXUYIgkTgk
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# LSeSZiv7evE
# 00001.wav
# 00002.wav
# MMTrblYIEgM
# 00001.wav
# MPkuYnDHS4E
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# NJygdnZs634
# 00001.wav
# 00002.wav
# 00003.wav
# PnSNt2F59-U
# 00001.wav
# 00002.wav
# RREb7K-SoSQ
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# 00019.wav
# 00020.wav
# 00021.wav
# 00022.wav
# 00023.wav
# 00024.wav
# 00025.wav
# 00026.wav
# 00027.wav
# 00028.wav
# SCFgvk0Sm24
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# WfkA4lUZwZ4
# 00001.wav
# WwguhI5dInQ
# 00001.wav
# Zxab80IZxU8
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# a3j4Vg7CtjA
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# bIi7FnNx6m0
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# dOnuu_9-nyI
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# 00019.wav
# 00020.wav
# 00021.wav
# 00022.wav
# 00023.wav
# 00024.wav
# 00025.wav
# 00026.wav
# 00027.wav
# 00028.wav
# 00029.wav
# 00030.wav
# 00031.wav
# 00032.wav
# 00033.wav
# 00034.wav
# 00035.wav
# 00036.wav
# 00037.wav
# 00038.wav
# 00039.wav
# 00040.wav
# 00041.wav
# 00042.wav
# 00043.wav
# 00044.wav
# 00045.wav
# fb31EtxsZDs
# 00001.wav
# hgB5ziAudzU
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# j0CaA8LPTdc
# 00001.wav
# 00002.wav
# 00003.wav
# k4l2cRqjT78
# 00001.wav
# l5sY-WWVnZM
# 00001.wav
# o524HaR7jfE
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# 00019.wav
# 00020.wav
# 00021.wav
# 00022.wav
# 00023.wav
# 00024.wav
# 00025.wav
# 00026.wav
# 00027.wav
# 00028.wav
# 00029.wav
# ocnz4PPv-RQ
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# pdTdefdQ_QI
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# uM5GCGOXVXc
# 00001.wav
# 00002.wav
# 00003.wav
# vpnw2jQlZn4
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# wg6IOBMAdOc
# 00001.wav
# ywRolvE7ToY
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 5VxX7ZI5z5s
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 5r-26vNFeJU
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 6ya9UpdRCPs
# 00001.wav
# 00002.wav
# 7QOGR0zvTxY
# 00001.wav
# 00002.wav
# 8rp9UYZp-zA
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# BuecddErOwU
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# CYb_opUpiw4
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# 00019.wav
# 00020.wav
# 00021.wav
# 00022.wav
# 00023.wav
# 00024.wav
# 00025.wav
# 00026.wav
# 00027.wav
# 00028.wav
# 00029.wav
# 00030.wav
# Pkfu9rKM5QA
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# Px9R6A3XKDM
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# PynZ3bQ3Ga4
# 00001.wav
# 00002.wav
# bNNIcOJGy4w
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# iwN6Hu6xyM0
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# pOJlOI5cDZw
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# qFUUDSjCy5M
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# uy0-9hpmHJs
# 00001.wav
# 00002.wav
# xH3Pp_5yxOk
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# 00019.wav
# 00020.wav
# 00021.wav
# 00022.wav
# 00023.wav
# xLakEK2bbQw
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 0gR9vlGI8ro
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 2fsToHH2Qz4
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 4UXieX7te0U
# 00001.wav
# 8WVqEfbZ4Ic
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 9tu4uaM0YTc
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# 00019.wav
# 00020.wav
# 00021.wav
# 00022.wav
# 00023.wav
# 00024.wav
# 00025.wav
# A-Q7SmHQT70
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# 00019.wav
# 00020.wav
# 00021.wav
# 00022.wav
# 00023.wav
# 00024.wav
# 00025.wav
# BaesL7QJLFU
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# 00019.wav
# 00020.wav
# 00021.wav
# 00022.wav
# 00023.wav
# 00024.wav
# 00025.wav
# 00026.wav
# 00027.wav
# 00028.wav
# EFFEzbt2k6o
# 00001.wav
# 00002.wav
# 00003.wav
# G4ytSwL9uak
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# Q7aBwU0ZeUk
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# RBlk-zGCm0g
# 00001.wav
# 00002.wav
# 00003.wav
# RM55SnIw2uQ
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# TIFdSOTYIBg
# 00001.wav
# 00002.wav
# YOjilzTiE-Y
# 00001.wav
# 00002.wav
# ZBioF6ulHg8
# 00001.wav
# aDIdItugOC0
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# eckQg181kQY
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# 00019.wav
# 00020.wav
# 00021.wav
# 00022.wav
# 00023.wav
# 00024.wav
# 00025.wav
# 00026.wav
# 00027.wav
# 00028.wav
# 00029.wav
# 00030.wav
# 00031.wav
# 00032.wav
# 00033.wav
# 00034.wav
# 00035.wav
# 00036.wav
# 00037.wav
# 00038.wav
# 00039.wav
# 00040.wav
# 00041.wav
# 00042.wav
# 00043.wav
# iYaSdx4Qhv4
# 00001.wav
# 00002.wav
# 00003.wav
# lCA6CCS7mxc
# 00001.wav
# pJcq28hEvHg
# 00001.wav
# sci80gk6bUc
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 00014.wav
# 00015.wav
# 00016.wav
# 00017.wav
# 00018.wav
# 00019.wav
# 00020.wav
# 00021.wav
# 00022.wav
# 00023.wav
# 00024.wav
# 00025.wav
# 00026.wav
# 00027.wav
# 00028.wav
# 00029.wav
# 00030.wav
# 00031.wav
# 00032.wav
# 00033.wav
# 00034.wav
# 00035.wav
# 00036.wav
# 00037.wav
# 00038.wav
# 00039.wav
# 00040.wav
# 00041.wav
# 00042.wav
# 00043.wav
# 00044.wav
# 00045.wav
# 00046.wav
# 00047.wav
# 00048.wav
# 00049.wav
# 00050.wav
# 00051.wav
# 00052.wav
# 00053.wav
# 00054.wav
# 00055.wav
# 00056.wav
# 00057.wav
# 00058.wav
# 00059.wav
# sqdHikUKOK0
# 00001.wav
# su3ku9D00jA
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# wyaUcxpHOQs
# 00001.wav
# 2vSPFNQoKmk
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# 00011.wav
# 00012.wav
# 00013.wav
# 5AfbbZolonc
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# ABpVMOt0WEE
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# FoACkHPFRTo
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# IipkRlgAGC0
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# 00010.wav
# KPM7HF0Xc18
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# KjHVVTWafJQ
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# N4ZN6AAv4vU
# 00001.wav
# 00002.wav
# 00003.wav
# XYGmvRZiNNg
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# YLTaZK6x2z8
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# cE3StI6Qw0w
# 00001.wav
# dCpykP6iJnA
# 00001.wav
# 00002.wav
# 00003.wav
# feJ12-OYVaU
# 00001.wav
# 00002.wav
# 00003.wav
# 00004.wav
# 00005.wav
# 00006.wav
# 00007.wav
# 00008.wav
# 00009.wav
# nSpt6fRmaV4
# 00001.wav
# vw9WhRtxRhE
# 00001.wav

# %%
# Each embedding saved file will have (2, 256)

for base_id in os.listdir(data_path):
    for video_id in os.listdir(os.path.join(data_path, base_id)):
        if video_id.startswith('.'): #hidden folders
            continue;
        for audio_id in os.listdir(os.path.join(data_path, base_id, video_id)):
            audio_path = os.path.join(data_path, base_id, video_id, audio_id)
# Out:
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/1zcIwhmdeo4/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/1zcIwhmdeo4/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/1zcIwhmdeo4/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7gWzIy6yIIk/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7gWzIy6yIIk/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7gWzIy6yIIk/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7gWzIy6yIIk/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7w0IBEWc9Qw/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7w0IBEWc9Qw/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7w0IBEWc9Qw/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7w0IBEWc9Qw/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7w0IBEWc9Qw/00005.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7w0IBEWc9Qw/00006.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7w0IBEWc9Qw/00007.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7w0IBEWc9Qw/00008.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7w0IBEWc9Qw/00009.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/7w0IBEWc9Qw/00010.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/9mQ11vBs1wc/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/9mQ11vBs1wc/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/9mQ11vBs1wc/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/9mQ11vBs1wc/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/DtdEYdViWdw/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/DtdEYdViWdw/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/DtdEYdViWdw/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00005.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00006.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00007.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00008.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00009.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00010.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00011.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00012.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00013.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00014.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00015.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00016.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00017.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00018.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00019.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00020.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00021.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00022.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00023.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00024.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00025.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/J9lHsKG98U8/00026.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/Y8hIVOBuels/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/Y8hIVOBuels/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/Y8hIVOBuels/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/Y8hIVOBuels/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/Y8hIVOBuels/00005.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/Y8hIVOBuels/00006.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/Y8hIVOBuels/00007.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/Y8hIVOBuels/00008.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/Y8hIVOBuels/00009.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/Y8hIVOBuels/00010.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/eWIX7sfn-M0/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/utrA-v8pPm4/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00005.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00006.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00007.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00008.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00009.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00010.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00011.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00012.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00013.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00014.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/zELwAz2W6hM/00015.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/0_laIeN-Q44/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/6WO410QOeuo/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/6WO410QOeuo/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/6WO410QOeuo/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/6WO410QOeuo/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/6WO410QOeuo/00005.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/6WO410QOeuo/00006.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/6WO410QOeuo/00007.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/6WO410QOeuo/00008.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/6WO410QOeuo/00009.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/6WO410QOeuo/00010.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/6WO410QOeuo/00011.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/C7k7C-PDvAA/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/C7k7C-PDvAA/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/Mpr9wqUuLQA/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/Mpr9wqUuLQA/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/Mpr9wqUuLQA/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00005.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00006.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00007.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00008.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00009.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00010.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00011.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00012.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00013.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00014.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00015.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00016.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00017.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00018.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00019.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00020.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00021.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00022.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00023.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00024.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00025.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00026.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00027.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00028.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QanuGhOhb9A/00029.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QnnjJ9i5WFs/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/QnnjJ9i5WFs/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00005.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00006.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00007.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00008.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00009.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00010.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00011.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00012.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00013.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00014.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00015.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00016.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00017.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00018.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00019.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00020.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00021.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00022.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00023.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00024.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00025.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00026.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00027.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00028.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00029.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00030.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00031.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00032.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00033.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00034.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00035.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/RLKKsYiCMvc/00036.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/SI4D2_YXvBE/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/TqUbiOgEb0w/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/TqUbiOgEb0w/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/TqUbiOgEb0w/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/TqUbiOgEb0w/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/TqUbiOgEb0w/00005.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/TqUbiOgEb0w/00006.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/TqUbiOgEb0w/00007.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/TqUbiOgEb0w/00008.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/TqUbiOgEb0w/00009.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/TqUbiOgEb0w/00010.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/VMaXdHLz5Bk/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/VMaXdHLz5Bk/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/VMaXdHLz5Bk/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/VMaXdHLz5Bk/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/VMaXdHLz5Bk/00005.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/Y2Gr1I2DO7M/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/cMGEuZ1zqXk/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/cMGEuZ1zqXk/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/cMGEuZ1zqXk/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/cMGEuZ1zqXk/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/eNc4LrrvV80/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/eNc4LrrvV80/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/eNc4LrrvV80/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/eNc4LrrvV80/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/eNc4LrrvV80/00005.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/eNc4LrrvV80/00006.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/eNc4LrrvV80/00007.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/eNc4LrrvV80/00008.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/eNc4LrrvV80/00009.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/eNc4LrrvV80/00010.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/eNc4LrrvV80/00011.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/eNc4LrrvV80/00012.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002/eNc4LrrvV80/00013.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10002
00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10019/feJ12-OYVaU/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10019/feJ12-OYVaU/00002.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10019/feJ12-OYVaU/00003.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10019/feJ12-OYVaU/00004.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10019/feJ12-OYVaU/00005.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10019/feJ12-OYVaU/00006.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10019/feJ12-OYVaU/00007.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10019/feJ12-OYVaU/00008.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10019/feJ12-OYVaU/00009.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10019/nSpt6fRmaV4/00001.wav
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10019/vw9WhRtxRhE/00001.wav

# %%
utter, sr = librosa.core.load(audio_path, sr=config.sr)
# lower bound of utterance length
utter_min_len = (config.tisv_frame *config.hop + config.window) * sr
# Get the duration
duration = librosa.get_duration(utter, sr)
# Duration of each window
duration_per_frame = (duration / utter.shape[0])
# print(f'Duration: {duration}\nDuration per frame: {duration_per_frame}s\nMin length of utterance: {utter_min_len * duration_per_frame}s')
tisv_frame_duration_s = utter_min_len * duration_per_frame
# voice activity detection
intervals = librosa.effects.split(utter, top_db=25)

# %%
for idx, current_interval in enumerate(intervals):
    utter_part = utter[current_interval[0]:current_interval[1]]

# %%
intervals
# Out:
# array([[ 5632, 72961]])

# %%
len(utter)
# Out:
# 72961

# %%
from VAD_segments import VAD_chunk

times, segs = VAD_chunk(2, audio_path)

# %%
times
# Out:
# [(0.4, 0.8),
#  (0.8, 1.2),
#  (1.2, 1.6),
#  (1.6, 2.0),
#  (2.0, 2.4),
#  (2.4, 2.8),
#  (2.8, 3.2),
#  (3.2, 3.6),
#  (3.6, 4.0),
#  (4.0, 4.4),
#  (4.4, 4.56)]

# %%
    for audio_file_name in os.listdir(folder):
        audio_path = os.path.join(folder, audio_file_name)
        audio_file_number = audio_file_name.split('.')[0].split('_')[1]
        utter, sr = librosa.core.load(
            audio_path, sr=config.sr)        # load audio
        # lower bound of utterance length
        utter_min_len = (config.tisv_frame *
                         config.hop + config.window) * sr
        # Get the duration
        duration = librosa.get_duration(utter, sr)
        # Duration of each window
        duration_per_frame = (duration / utter.shape[0])
#             print(f'Duration: {duration}\nDuration per frame: {duration_per_frame}s\nMin length of utterance: {utter_min_len * duration_per_frame}s')
        tisv_frame_duration_s = utter_min_len * duration_per_frame
        intervals = librosa.effects.split(
            utter, top_db=vad_threshold)         # voice activity detection

        for idx, current_interval in enumerate(intervals):
            utterances_spec = []
            # save first and last 160 frames of spectrogram.
            utter_part = utter[current_interval[0]:current_interval[1]]
            S = librosa.core.stft(y=utter_part, n_fft=config.nfft,
                                  win_length=int(config.window * sr), hop_length=int(config.hop * sr))
            S = np.abs(S) ** 2
            mel_basis = librosa.filters.mel(
                sr=sr, n_fft=config.nfft, n_mels=40)
            # log mel spectrogram of utterances
            S = np.log10(np.dot(mel_basis, S) + 1e-6)
        #         print(S.shape)
            utterances_spec.append(S[:, :config.tisv_frame])
            utterances_spec.append(S[:, -config.tisv_frame:])

            utterances_spec = np.array(utterances_spec)
            utter_batch = np.transpose(utterances_spec, axes=(
                2, 0, 1))     # transpose [frames, batch, n_mels]
        #         print(utter_batch.shape)

            data = sess.run(embedded, feed_dict={verif: utter_batch})
            save_embedding_path = os.path.join(
                save_dir_path, f'vctk-{speakerid}-{audio_file_number}-{idx}.npy')
            np.save(save_embedding_path, data)
#                 print(data.shape)
# Out:
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/.DS_Store
# /home/jovyan/work/datasets/voxceleb-1/sample/wav/id10001/1zcIwhmdeo4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_150/1184618237.py in <module>
#       9         if audio_file_name.startswith('.'): #hidden folders
#      10             continue;
# ---> 11         audio_file_number = audio_file_name.split('.')[0].split('_')[1]
#      12         utter, sr = librosa.core.load(
#      13             audio_path, sr=config.sr)        # load audio
#
# IndexError: list index out of range

# %% [markdown]
# ## structuring the dataset

# %%
from collections import defaultdict
list_of_embedding_path = sorted(os.listdir(save_dir_path))
print(f'Total number of files {len(list_of_embedding_path)}')
list_of_embedding_path[:5]

embedding_dict = defaultdict(list)

for file in list_of_embedding_path:
    embedding_dict[file.split('-')[1]].append(os.path.join(save_dir_path, file))

for key in embedding_dict:
    if len(embedding_dict[key]) < 5: # remove the keys if its embeddings is less than 5
        embedding_dict.pop(key)
        print(f'Poped {key}')

def shuffle_two(dict_of_two, train_sequence_path, train_ids):
    """Shuffle the given 2 labels"""
    max_to_pick = 5
    key1, key2 = dict_of_two.keys()
#     print(len(dict_of_two[key1]), len(dict_of_two[key2]))
    while dict_of_two[key1] and dict_of_two[key2]:
#         print('in while')
        no_to_pick = np.random.randint(1, max_to_pick)
        if no_to_pick <= len(dict_of_two[key1]):
#             print(no_to_pick, len(dict_of_two[key1]))
            train_sequence_path.extend(dict_of_two[key1][:no_to_pick])
            del dict_of_two[key1][:no_to_pick]
            train_ids.extend([key1] * no_to_pick)
        else: break
        no_to_pick = np.random.randint(1, max_to_pick)
        if no_to_pick <= len(dict_of_two[key2]):
#             print(no_to_pick)
            train_sequence_path.extend(dict_of_two[key2][:no_to_pick])
            del dict_of_two[key2][:no_to_pick]
            train_ids.extend([key2] * no_to_pick)
        else: break
    no_to_pick = len(dict_of_two[key1])
    train_sequence_path.extend(dict_of_two[key1])
    train_ids.extend([key1] * no_to_pick)
    no_to_pick = len(dict_of_two[key2])
    train_sequence_path.extend(dict_of_two[key2])
    train_ids.extend([key2] * no_to_pick)
# Out:
# Total number of files 93417

# %%
train_sequence_path = []
train_ids = []
while len(embedding_dict) >= 2:
    first2pairs = {k: embedding_dict[k] for k in list(embedding_dict)[:2]}
    shuffle_two(first2pairs, train_sequence_path, train_ids)
    # remove the keys from embedding_dict
    for key in first2pairs:
        embedding_dict.pop(key)
print(len(embedding_dict), len(train_sequence_path), len(train_ids))
# Out:
# 0 93417 93417

# %%
# train_sequence_path[81234:81239], train_ids[81234:81239]

# %%
train_sequence = []
train_cluster_id = []
for idx, item in enumerate(train_sequence_path):
    embeddings = np.load(item)
    train_sequence.extend(embeddings.tolist())
    train_cluster_id.extend([train_ids[idx], train_ids[idx]])
#     break

# %%
len(train_sequence), len(train_cluster_id)
# Out:
# (186834, 186834)

# %%
np.savez('/datadrive/dalon/diarizer-dataset/VCTK-Corpus/vctk_training_data.npz',
         train_sequence=train_sequence, train_cluster_id=train_cluster_id)

# %% [markdown]
# # Prepare test dataset

# %%
videoid = 'zPFptdATk_s'
save_utter_label_interval = f'/datadrive/dalon/uis-rnn/Notebooks/{videoid}_5min.b'
save_test_data = f'/datadrive/dalon/uis-rnn/Notebooks/{videoid}_test.npz' # it will have embeddings and data

# %%
with open(save_utter_label_interval, 'rb') as f:
    _tmp = pickle.load(f)

# %%
embeddings = []
# Each embedding saved file will have (2, 256)
with tf.Session(config=config_tensorflow) as sess:
    tf.global_variables_initializer().run()
    saver.restore(sess, model_path)

    utter = _tmp['utter']
    sr = config.sr
    utter_min_len = (config.tisv_frame * config.hop + config.window) * sr    # lower bound of utterance length
    # Get the duration
    duration = librosa.get_duration(utter, sr)
    # Duration of each window
    duration_per_frame = (duration / utter.shape[0])
#             print(f'Duration: {duration}\nDuration per frame: {duration_per_frame}s\nMin length of utterance: {utter_min_len * duration_per_frame}s')
    tisv_frame_duration_s = utter_min_len * duration_per_frame
    intervals = _tmp['intervals']

    for idx, current_interval in enumerate(intervals):
        utterances_spec = []
        utter_part = utter[current_interval[0]:current_interval[1]]         # save first and last 160 frames of spectrogram.
        S = librosa.core.stft(y=utter_part, n_fft=config.nfft,
                              win_length=int(config.window * sr), hop_length=int(config.hop * sr))
        S = np.abs(S) ** 2
        mel_basis = librosa.filters.mel(sr=sr, n_fft=config.nfft, n_mels=40)
        S = np.log10(np.dot(mel_basis, S) + 1e-6)           # log mel spectrogram of utterances
#         print(S.shape)
        utterances_spec.append(S[:, :config.tisv_frame])
        utterances_spec.append(S[:, -config.tisv_frame:])

        utterances_spec = np.array(utterances_spec)
        utter_batch = np.transpose(utterances_spec, axes=(2,0,1))     # transpose [frames, batch, n_mels]
        data = sess.run(embedded, feed_dict={verif:utter_batch})
        embeddings.extend(data)
# Out:
# INFO:tensorflow:Restoring parameters from /datadrive/dalon/models/m-64-10-768-256/Check_Point/model.ckpt-46

# %%
test_cluster_ids = []
for item in _tmp['labels_list']:
    test_cluster_ids.extend([item, item])

# %%
len(test_cluster_ids)
# Out:
# 542

# %%
np.savez(save_test_data,
         test_sequences=embeddings,
         test_cluster_ids=test_cluster_ids)

# %% [markdown]
# # Create single npz file for testing

# %%
videoids = ['zPFptdATk_s', 'VqF96Um0HQw']
save_test_files = []
for videoid in videoids:
    save_test_files.append(f'/datadrive/dalon/uis-rnn/Notebooks/{videoid}_test.npz')

# %%
test_sequences = []
test_cluster_ids = []

# %%
512//125
# Out:
# 4

# %%
# convert these into smaller chunks
def split_to_chunks(test_sequences, test_cluster_ids, ids, seqs):
    max_size = 125
    start = 0
    for i in range(len(ids) // max_size):
        test_sequences.append(seqs[start:max_size * (i + 1)])
        test_cluster_ids.append(ids[start:max_size * (i + 1)])
        start = max_size * (i + 1)
    test_sequences.append(seqs[start:])
    test_cluster_ids.append(ids[start:])

# %%
for file in save_test_files:
    _tmp = np.load(file)
    if len(list(_tmp['test_cluster_ids'])) > 150:
        split_to_chunks(test_sequences,
                        test_cluster_ids,
                        list(_tmp['test_cluster_ids']),
                        np.float64(_tmp['test_sequences']))
    else:
        test_sequences.append(np.float64(_tmp['test_sequences']))
        test_cluster_ids.append(list(_tmp['test_cluster_ids']))

# %%
test_sequences = np.array(test_sequences)
test_cluster_ids = np.array(test_cluster_ids)

# %%
test_data_path = '/datadrive/dalon/uis-rnn/data/testing_data_custom_2vid.npz'
np.savez(test_data_path,
         test_sequences=test_sequences,
         test_cluster_ids=test_cluster_ids)
